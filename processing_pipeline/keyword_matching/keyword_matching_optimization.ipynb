# %%
from pathlib import Path

from constants.abs_paths import AbsDirPath
import pandas as pd

# %%
file_dir = AbsDirPath.KEYWORDS_MATCHING

def load_all_files(dir: Path):
    dfs = []
    for file_path in dir.glob("*.parquet"):
        try:
            file = pd.read_parquet(file_path)
            # file['fname'] = file_path
            dfs.append(file)
            print(f"Loaded {file_path}")
        except:
            print(f"Error while loading {file_path}")

    df = pd.concat(dfs)
    return df


df = load_all_files(file_dir)
# Out:
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\allenai.scispacy.v0.5.5.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\allenai.scispacy.v0.5.5.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\allenai.scispacy.v0.5.5.issue.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\allenai.scispacy.v0.5.5.issue_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\allenai.scispacy.v0.5.5.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.issue.0.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.issue.1.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.issue.2.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.issue_comment.0.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.issue_comment.1.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.issue_comment.2.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\google.deepvariant.v1.6.1.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\OpenGene.fastp.v0.23.4.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\OpenGene.fastp.v0.23.4.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\OpenGene.fastp.v0.23.4.issue.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\OpenGene.fastp.v0.23.4.issue_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\OpenGene.fastp.v0.23.4.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.00.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.01.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.02.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.03.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.04.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.05.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.06.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.07.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.08.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.09.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.10.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.11.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.12.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.13.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.14.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.15.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.16.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.17.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.18.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.19.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.20.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.code_comment.21.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.00.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.01.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.02.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.03.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.04.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.05.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.06.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.07.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.08.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.09.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.10.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.11.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.12.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.13.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.14.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.15.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.16.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.17.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.18.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.19.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.20.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.21.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.22.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.23.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.24.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.25.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.26.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.27.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.28.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.docs.29.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.00.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.01.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.02.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.03.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.04.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.05.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.06.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.07.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.08.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue.09.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.0.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.1.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.2.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.3.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.4.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.5.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.6.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.7.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.issue_comment.8.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\root-project.root.v6-32-06.wiki.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.issue.0.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.issue.1.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.issue.2.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.issue.3.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.issue_comment.0.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.issue_comment.1.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.issue_comment.2.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\matched\scverse.scanpy.1.10.2.wiki.parquet

# %%
df.head()
# Out:
#    keyword keyword_raw matched_word  match_idx  \
# 0   releas      releas      release         28
# 1  version     version     versions        150
# 2  version     version      version        172
# 3   instal      instal      install        297
# 4  version     version     versions        150
#
#                                             sentence             qa  \
# 0  Instructions for creating a release of the sci...  deployability
# 1  Instructions for creating a release of the sci...  deployability
# 2  Instructions for creating a release of the sci...  deployability
# 3  Instructions for creating a release of the sci...  deployability
# 4  Instructions for creating a release of the sci...  integrability
#
#          source                                                url  \
# 0  code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 1  code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 2  code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 3  code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 4  code_comment  https://github.com/allenai/scispacy/tree/v0.5....
#
#                    repo_id
# 0  allenai/scispacy/v0.5.5
# 1  allenai/scispacy/v0.5.5
# 2  allenai/scispacy/v0.5.5
# 3  allenai/scispacy/v0.5.5
# 4  allenai/scispacy/v0.5.5

# %%
df.shape
# Out:
# (1994850, 9)

# %% [markdown]
# ## Reduce dataset size based on lowercase matched keywords
# Preserve original matched words and count of matches...

# %%
df.groupby("matched_word").size()
# Out:
# matched_word
# A/B            24
# A/b             6
# ACCESS          2
# ADAPTERS        4
# ADAPTIVE       56
#                ..
# xmlreader       1
# xmlreadfile     1
# xmlrpc          1
# xmls            1
# xmlsoft         1
# Length: 18947, dtype: int64

# %%
df["matched_word_lw"] = df.matched_word.str.lower()

# %%
df.groupby("matched_word_lw").size()
# Out:
# matched_word_lw
# a/b                       67
# abstract                3232
# abstract-class             2
# abstract-declarator       76
# abstract-declarators       6
#                         ...
# xmlsoft                    1
# xmlsummary-exception       2
# xmltag                     2
# xmlwriteobject             1
# xss-protection             1
# Length: 15916, dtype: int64

# %%
matched_word_df = df.groupby("matched_word_lw").matched_word.agg(unique_matched_words=("unique"), nunique_matched_words=("nunique"))
matched_word_df
# Out:
#                         unique_matched_words  nunique_matched_words
# matched_word_lw
# a/b                          [a/b, A/B, A/b]                      3
# abstract                [abstract, Abstract]                      2
# abstract-class              [abstract-class]                      1
# abstract-declarator    [abstract-declarator]                      1
# abstract-declarators  [abstract-declarators]                      1
# ...                                      ...                    ...
# xmlsoft                            [xmlsoft]                      1
# xmlsummary-exception  [XMLSummary-exception]                      1
# xmltag                              [XMLTag]                      1
# xmlwriteobject              [XmlWriteObject]                      1
# xss-protection              [Xss-Protection]                      1
#
# [15916 rows x 2 columns]

# %%
df = pd.merge(df, matched_word_df, "left", "matched_word_lw")
df
# Out:
#          keyword keyword_raw   matched_word  match_idx  \
# 0         releas      releas        release         28
# 1        version     version       versions        150
# 2        version     version        version        172
# 3         instal      instal        install        297
# 4        version     version       versions        150
# ...          ...         ...            ...        ...
# 1994845   visual      visual  visualization      14290
# 1994846    simpl       simpl     simplified      14350
# 1994847  consist     consist   consistently      16512
# 1994848   visual      visual  visualization      18552
# 1994849   visual      visual  Visualization      20055
#
#                                                   sentence             qa  \
# 0        Instructions for creating a release of the sci...  deployability
# 1        Instructions for creating a release of the sci...  deployability
# 2        Instructions for creating a release of the sci...  deployability
# 3        Instructions for creating a release of the sci...  deployability
# 4        Instructions for creating a release of the sci...  integrability
# ...                                                    ...            ...
# 1994845  data.obsm) (0:00:13). sc.pl.draw_graph(adata, ...      usability
# 1994846  5_clusters", legend_loc="on data"). This still...      usability
# 1994847   "18"],. *[. "19/Neu",. "20/Mk",. "21",. ],. *...      usability
# 1994848  nces, however, are only cosmetic. We had to ch...      usability
# 1994849  . Select some of the marker gene names. gene_n...      usability
#
#                source                                                url  \
# 0        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 1        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 2        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 3        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 4        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# ...               ...                                                ...
# 1994845          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
# 1994846          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
# 1994847          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
# 1994848          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
# 1994849          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
#
#                          repo_id matched_word_lw  \
# 0        allenai/scispacy/v0.5.5         release
# 1        allenai/scispacy/v0.5.5        versions
# 2        allenai/scispacy/v0.5.5         version
# 3        allenai/scispacy/v0.5.5         install
# 4        allenai/scispacy/v0.5.5        versions
# ...                          ...             ...
# 1994845    scverse/scanpy/1.10.2   visualization
# 1994846    scverse/scanpy/1.10.2      simplified
# 1994847    scverse/scanpy/1.10.2    consistently
# 1994848    scverse/scanpy/1.10.2   visualization
# 1994849    scverse/scanpy/1.10.2   visualization
#
#                                   unique_matched_words  nunique_matched_words
# 0                 [release, Release, RELEASE, RELease]                      4
# 1                       [versions, Versions, VERSIONS]                      3
# 2                 [version, VERSION, Version, VERsion]                      4
# 3                          [install, Install, INSTALL]                      3
# 4                       [versions, Versions, VERSIONS]                      3
# ...                                                ...                    ...
# 1994845  [visualization, Visualization, VISUALIZATION]                      3
# 1994846           [simplified, Simplified, SIMPLIFIED]                      3
# 1994847                   [consistently, Consistently]                      2
# 1994848  [visualization, Visualization, VISUALIZATION]                      3
# 1994849  [visualization, Visualization, VISUALIZATION]                      3
#
# [1994850 rows x 12 columns]

# %%
df = df.drop(columns="matched_word")
df = df.rename(columns={"matched_word_lw": "matched_word"})
df
# Out:
#          keyword keyword_raw  match_idx  \
# 0         releas      releas         28
# 1        version     version        150
# 2        version     version        172
# 3         instal      instal        297
# 4        version     version        150
# ...          ...         ...        ...
# 1994845   visual      visual      14290
# 1994846    simpl       simpl      14350
# 1994847  consist     consist      16512
# 1994848   visual      visual      18552
# 1994849   visual      visual      20055
#
#                                                   sentence             qa  \
# 0        Instructions for creating a release of the sci...  deployability
# 1        Instructions for creating a release of the sci...  deployability
# 2        Instructions for creating a release of the sci...  deployability
# 3        Instructions for creating a release of the sci...  deployability
# 4        Instructions for creating a release of the sci...  integrability
# ...                                                    ...            ...
# 1994845  data.obsm) (0:00:13). sc.pl.draw_graph(adata, ...      usability
# 1994846  5_clusters", legend_loc="on data"). This still...      usability
# 1994847   "18"],. *[. "19/Neu",. "20/Mk",. "21",. ],. *...      usability
# 1994848  nces, however, are only cosmetic. We had to ch...      usability
# 1994849  . Select some of the marker gene names. gene_n...      usability
#
#                source                                                url  \
# 0        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 1        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 2        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 3        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# 4        code_comment  https://github.com/allenai/scispacy/tree/v0.5....
# ...               ...                                                ...
# 1994845          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
# 1994846          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
# 1994847          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
# 1994848          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
# 1994849          wiki  https://scanpy.readthedocs.io/en/stable/tutori...
#
#                          repo_id   matched_word  \
# 0        allenai/scispacy/v0.5.5        release
# 1        allenai/scispacy/v0.5.5       versions
# 2        allenai/scispacy/v0.5.5        version
# 3        allenai/scispacy/v0.5.5        install
# 4        allenai/scispacy/v0.5.5       versions
# ...                          ...            ...
# 1994845    scverse/scanpy/1.10.2  visualization
# 1994846    scverse/scanpy/1.10.2     simplified
# 1994847    scverse/scanpy/1.10.2   consistently
# 1994848    scverse/scanpy/1.10.2  visualization
# 1994849    scverse/scanpy/1.10.2  visualization
#
#                                   unique_matched_words  nunique_matched_words
# 0                 [release, Release, RELEASE, RELease]                      4
# 1                       [versions, Versions, VERSIONS]                      3
# 2                 [version, VERSION, Version, VERsion]                      4
# 3                          [install, Install, INSTALL]                      3
# 4                       [versions, Versions, VERSIONS]                      3
# ...                                                ...                    ...
# 1994845  [visualization, Visualization, VISUALIZATION]                      3
# 1994846           [simplified, Simplified, SIMPLIFIED]                      3
# 1994847                   [consistently, Consistently]                      2
# 1994848  [visualization, Visualization, VISUALIZATION]                      3
# 1994849  [visualization, Visualization, VISUALIZATION]                      3
#
# [1994850 rows x 11 columns]

# %% [markdown]
# ## Clean sentences

# %%
df.sentence = df.sentence.str.replace(r"((\t|\r) ?)+", " ", regex=True)

# %%
df.sentence = df.sentence.str.replace(r"[ \"'#]{2,}", " ", regex=True)

# %% [markdown]
# ## Assign IDs to similar items
# Similar items are considered the ones that have all the similar parameters but the match idx
#
# Also remove match idx, as it is not used

# %%
df = df.drop(columns="match_idx")

# %%
import hashlib

quick_hash = lambda x: hashlib.md5(x.encode('utf-8')).hexdigest()

df["sentence_hash"] = df['sentence'].apply(quick_hash)

# %%
df.head()
# Out:
#    keyword keyword_raw                                           sentence  \
# 0   releas      releas  Instructions for creating a release of the sci...
# 1  version     version  Instructions for creating a release of the sci...
# 2  version     version  Instructions for creating a release of the sci...
# 3   instal      instal  Instructions for creating a release of the sci...
# 4  version     version  Instructions for creating a release of the sci...
#
#               qa        source  \
# 0  deployability  code_comment
# 1  deployability  code_comment
# 2  deployability  code_comment
# 3  deployability  code_comment
# 4  integrability  code_comment
#
#                                                  url                  repo_id  \
# 0  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
# 1  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
# 2  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
# 3  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
# 4  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
#
#   matched_word                  unique_matched_words  nunique_matched_words  \
# 0      release  [release, Release, RELEASE, RELease]                      4
# 1     versions        [versions, Versions, VERSIONS]                      3
# 2      version  [version, VERSION, Version, VERsion]                      4
# 3      install           [install, Install, INSTALL]                      3
# 4     versions        [versions, Versions, VERSIONS]                      3
#
#                       sentence_hash
# 0  cf6888bff796a44abdd39ef97fa94682
# 1  cf6888bff796a44abdd39ef97fa94682
# 2  cf6888bff796a44abdd39ef97fa94682
# 3  cf6888bff796a44abdd39ef97fa94682
# 4  cf6888bff796a44abdd39ef97fa94682

# %%
df['id'] = df.repo_id + "." + df.source + "." + df.qa + "." +  df.sentence_hash + "." + df.keyword + "." +df.matched_word
df.head()
# Out:
#    keyword keyword_raw                                           sentence  \
# 0   releas      releas  Instructions for creating a release of the sci...
# 1  version     version  Instructions for creating a release of the sci...
# 2  version     version  Instructions for creating a release of the sci...
# 3   instal      instal  Instructions for creating a release of the sci...
# 4  version     version  Instructions for creating a release of the sci...
#
#               qa        source  \
# 0  deployability  code_comment
# 1  deployability  code_comment
# 2  deployability  code_comment
# 3  deployability  code_comment
# 4  integrability  code_comment
#
#                                                  url                  repo_id  \
# 0  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
# 1  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
# 2  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
# 3  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
# 4  https://github.com/allenai/scispacy/tree/v0.5....  allenai/scispacy/v0.5.5
#
#   matched_word                  unique_matched_words  nunique_matched_words  \
# 0      release  [release, Release, RELEASE, RELease]                      4
# 1     versions        [versions, Versions, VERSIONS]                      3
# 2      version  [version, VERSION, Version, VERsion]                      4
# 3      install           [install, Install, INSTALL]                      3
# 4     versions        [versions, Versions, VERSIONS]                      3
#
#                       sentence_hash  \
# 0  cf6888bff796a44abdd39ef97fa94682
# 1  cf6888bff796a44abdd39ef97fa94682
# 2  cf6888bff796a44abdd39ef97fa94682
# 3  cf6888bff796a44abdd39ef97fa94682
# 4  cf6888bff796a44abdd39ef97fa94682
#
#                                                   id
# 0  allenai/scispacy/v0.5.5.code_comment.deployabi...
# 1  allenai/scispacy/v0.5.5.code_comment.deployabi...
# 2  allenai/scispacy/v0.5.5.code_comment.deployabi...
# 3  allenai/scispacy/v0.5.5.code_comment.deployabi...
# 4  allenai/scispacy/v0.5.5.code_comment.integrabi...

# %%
df["nsimilar"] = df.groupby("id").transform("size")
df = df.groupby("id").first()
df.head()
# Out:
#                                                    keyword keyword_raw  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  operat      operat
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   error       error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   error       error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   error       error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   avail       avail
#
#                                                                                              sentence  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                  operation, extra bits, table bits
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  the deflate stream. The end-of-block will not ...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...       error message zlib inflate or deflate stream
# OpenGene/fastp/v0.23.4.code_comment.availabilit...        got a data error -- remain here until reset
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  Reads the given number of uncompressed bytes f...
#
#                                                               qa  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
#
#                                                           source  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
#
#                                                                                                   url  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
#
#                                                                    repo_id  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
#
#                                                    matched_word  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...    operation
# OpenGene/fastp/v0.23.4.code_comment.availabilit...        error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...        error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...        error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...    available
#
#                                                                  unique_matched_words  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  [operation, Operation, OPERATION]
# OpenGene/fastp/v0.23.4.code_comment.availabilit...       [error, Error, ERROR, ERRor]
# OpenGene/fastp/v0.23.4.code_comment.availabilit...       [error, Error, ERROR, ERRor]
# OpenGene/fastp/v0.23.4.code_comment.availabilit...       [error, Error, ERROR, ERRor]
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  [available, Available, AVAILABLE]
#
#                                                     nunique_matched_words  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      3
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      3
#
#                                                                        sentence_hash  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  000cad13737d3a722a73ad7f4a899284
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  02196d1c2fdd3a15ac28c390d89c912d
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  02bb6a79eb91bde81c5280dd968caf74
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  052281e940b33f7a25cbfbda33534cd3
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  0612a949907db33bbb0cb741c8964768
#
#                                                     similar_count
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...              1
# OpenGene/fastp/v0.23.4.code_comment.availabilit...              1
# OpenGene/fastp/v0.23.4.code_comment.availabilit...              1
# OpenGene/fastp/v0.23.4.code_comment.availabilit...              1
# OpenGene/fastp/v0.23.4.code_comment.availabilit...              1

# %% [markdown]
# ### Matched word clean up results: before and after

# %%
df.groupby("keyword").nsimilar.agg(["sum", "count"]).sum(axis=0)
# Out:
# sum      1994850
# count    1601472
# dtype: int64

# %%
df.groupby("keyword").nsimilar.agg(["sum", "count"]).sum(axis=0)
# Out:
# sum      1994850
# count    1601472
# dtype: int64

# %%
df.groupby("keyword").nsimilar.agg(["sum", "count"])
# Out:
#             sum  count
# keyword
# a/b          67     49
# abstract   4814   3502
# access    10041   8574
# accid       313    285
# adapt      7949   5769
# ...         ...    ...
# worm          7      6
# wrap       4549   3930
# wrapper    2321   1934
# xml        1760   1285
# xss           1      1
#
# [523 rows x 2 columns]

# %% [markdown]
# ## Output to optimized folder

# %%
df.head()
# Out:
#                                                    keyword keyword_raw  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  operat      operat
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   error       error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   error       error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   error       error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   avail       avail
#
#                                                                                              sentence  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                  operation, extra bits, table bits
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  the deflate stream. The end-of-block will not ...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...       error message zlib inflate or deflate stream
# OpenGene/fastp/v0.23.4.code_comment.availabilit...        got a data error -- remain here until reset
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  Reads the given number of uncompressed bytes f...
#
#                                                               qa  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  availability
#
#                                                           source  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  code_comment
#
#                                                                                                   url  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  https://github.com/OpenGene/fastp/tree/v0.23.4...
#
#                                                                    repo_id  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  OpenGene/fastp/v0.23.4
#
#                                                    matched_word  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...    operation
# OpenGene/fastp/v0.23.4.code_comment.availabilit...        error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...        error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...        error
# OpenGene/fastp/v0.23.4.code_comment.availabilit...    available
#
#                                                                  unique_matched_words  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  [operation, Operation, OPERATION]
# OpenGene/fastp/v0.23.4.code_comment.availabilit...       [error, Error, ERROR, ERRor]
# OpenGene/fastp/v0.23.4.code_comment.availabilit...       [error, Error, ERROR, ERRor]
# OpenGene/fastp/v0.23.4.code_comment.availabilit...       [error, Error, ERROR, ERRor]
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  [available, Available, AVAILABLE]
#
#                                                     nunique_matched_words  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      3
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      4
# OpenGene/fastp/v0.23.4.code_comment.availabilit...                      3
#
#                                                                        sentence_hash  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  000cad13737d3a722a73ad7f4a899284
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  02196d1c2fdd3a15ac28c390d89c912d
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  02bb6a79eb91bde81c5280dd968caf74
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  052281e940b33f7a25cbfbda33534cd3
# OpenGene/fastp/v0.23.4.code_comment.availabilit...  0612a949907db33bbb0cb741c8964768
#
#                                                     nsimilar
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...         1
# OpenGene/fastp/v0.23.4.code_comment.availabilit...         1
# OpenGene/fastp/v0.23.4.code_comment.availabilit...         1
# OpenGene/fastp/v0.23.4.code_comment.availabilit...         1
# OpenGene/fastp/v0.23.4.code_comment.availabilit...         1

# %%
df.drop_duplicates(["repo_id", "source"])[["repo_id", "source"]]
# Out:
#                                                                        repo_id  \
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...      OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.docs.availability.0b95c5...      OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.issue.availability.02942...      OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.issue_comment.availabili...      OpenGene/fastp/v0.23.4
# OpenGene/fastp/v0.23.4.release.availability.547...      OpenGene/fastp/v0.23.4
# allenai/scispacy/v0.5.5.code_comment.availabili...     allenai/scispacy/v0.5.5
# allenai/scispacy/v0.5.5.docs.availability.09064...     allenai/scispacy/v0.5.5
# allenai/scispacy/v0.5.5.issue.availability.0025...     allenai/scispacy/v0.5.5
# allenai/scispacy/v0.5.5.issue_comment.availabil...     allenai/scispacy/v0.5.5
# allenai/scispacy/v0.5.5.release.availability.4d...     allenai/scispacy/v0.5.5
# google/deepvariant/v1.6.1.code_comment.availabi...   google/deepvariant/v1.6.1
# google/deepvariant/v1.6.1.docs.availability.001...   google/deepvariant/v1.6.1
# google/deepvariant/v1.6.1.issue.availability.00...   google/deepvariant/v1.6.1
# google/deepvariant/v1.6.1.issue_comment.availab...   google/deepvariant/v1.6.1
# google/deepvariant/v1.6.1.release.availability....   google/deepvariant/v1.6.1
# root-project/root/v6-32-06.code_comment.availab...  root-project/root/v6-32-06
# root-project/root/v6-32-06.docs.availability.00...  root-project/root/v6-32-06
# root-project/root/v6-32-06.issue.availability.0...  root-project/root/v6-32-06
# root-project/root/v6-32-06.issue_comment.availa...  root-project/root/v6-32-06
# root-project/root/v6-32-06.release.availability...  root-project/root/v6-32-06
# root-project/root/v6-32-06.wiki.availability.00...  root-project/root/v6-32-06
# scverse/scanpy/1.10.2.code_comment.availability...       scverse/scanpy/1.10.2
# scverse/scanpy/1.10.2.docs.availability.00c15d0...       scverse/scanpy/1.10.2
# scverse/scanpy/1.10.2.issue.availability.003d4b...       scverse/scanpy/1.10.2
# scverse/scanpy/1.10.2.issue_comment.availabilit...       scverse/scanpy/1.10.2
# scverse/scanpy/1.10.2.wiki.availability.023a274...       scverse/scanpy/1.10.2
#
#                                                            source
# id
# OpenGene/fastp/v0.23.4.code_comment.availabilit...   code_comment
# OpenGene/fastp/v0.23.4.docs.availability.0b95c5...           docs
# OpenGene/fastp/v0.23.4.issue.availability.02942...          issue
# OpenGene/fastp/v0.23.4.issue_comment.availabili...  issue_comment
# OpenGene/fastp/v0.23.4.release.availability.547...        release
# allenai/scispacy/v0.5.5.code_comment.availabili...   code_comment
# allenai/scispacy/v0.5.5.docs.availability.09064...           docs
# allenai/scispacy/v0.5.5.issue.availability.0025...          issue
# allenai/scispacy/v0.5.5.issue_comment.availabil...  issue_comment
# allenai/scispacy/v0.5.5.release.availability.4d...        release
# google/deepvariant/v1.6.1.code_comment.availabi...   code_comment
# google/deepvariant/v1.6.1.docs.availability.001...           docs
# google/deepvariant/v1.6.1.issue.availability.00...          issue
# google/deepvariant/v1.6.1.issue_comment.availab...  issue_comment
# google/deepvariant/v1.6.1.release.availability....        release
# root-project/root/v6-32-06.code_comment.availab...   code_comment
# root-project/root/v6-32-06.docs.availability.00...           docs
# root-project/root/v6-32-06.issue.availability.0...          issue
# root-project/root/v6-32-06.issue_comment.availa...  issue_comment
# root-project/root/v6-32-06.release.availability...        release
# root-project/root/v6-32-06.wiki.availability.00...           wiki
# scverse/scanpy/1.10.2.code_comment.availability...   code_comment
# scverse/scanpy/1.10.2.docs.availability.00c15d0...           docs
# scverse/scanpy/1.10.2.issue.availability.003d4b...          issue
# scverse/scanpy/1.10.2.issue_comment.availabilit...  issue_comment
# scverse/scanpy/1.10.2.wiki.availability.023a274...           wiki

# %%
output_dir = AbsDirPath.OPTIMIZED_KEYWORDS
output_dir.mkdir(exist_ok=True)

for repo_id, source in df.drop_duplicates(["repo_id", "source"])[["repo_id", "source"]].values:
    output_file = output_dir / f"{repo_id.replace("/", ".")}.{source}.parquet"
    print(output_file)
    df[(df.source == source) & (df.repo_id == repo_id)].to_parquet(output_file, engine='pyarrow', compression='snappy', index=False)
    print(f"Saved {output_file}")
# Out:
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.code_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.code_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.docs.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.docs.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.issue.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.issue.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.issue_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.issue_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.release.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\OpenGene.fastp.v0.23.4.release.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.code_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.code_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.docs.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.docs.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.issue.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.issue.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.issue_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.issue_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.release.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\allenai.scispacy.v0.5.5.release.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.code_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.code_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.docs.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.docs.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.issue.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.issue.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.issue_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.issue_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.release.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\google.deepvariant.v1.6.1.release.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.code_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.code_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.docs.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.docs.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.issue.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.issue.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.issue_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.issue_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.release.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.release.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.wiki.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\root-project.root.v6-32-06.wiki.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.code_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.code_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.docs.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.docs.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.issue.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.issue.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.issue_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.issue_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.wiki.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords\optimized\scverse.scanpy.1.10.2.wiki.parquet
