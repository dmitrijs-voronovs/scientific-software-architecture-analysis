# %% [markdown]
# ## Load data

# %%
from processing_pipeline.data_optimization.stage_cfg import COLUMNS_FOR_SPLITTING_DATA, S3TacticExtraction, \
    S2ArchRelevance

stage = S3TacticExtraction
# stage = S2ArchRelevance

# %%
sdf = stage.load_stage_df()
sdf.shape
# Out:
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s3_tactic_extraction\allenai.scispacy.v0.5.5.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s3_tactic_extraction\allenai.scispacy.v0.5.5.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s3_tactic_extraction\allenai.scispacy.v0.5.5.issue_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s3_tactic_extraction\allenai.scispacy.v0.5.5.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s3_tactic_extraction\OpenGene.fastp.v0.23.4.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s3_tactic_extraction\OpenGene.fastp.v0.23.4.docs.parquet
# ...

# %% [markdown]
# ## Optimize data

# %%
dfo = stage.apply_filters_till_current(keep_all_data=True)
dfo.shape
# Out:
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.issue.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.issue_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\google.deepvariant.v1.6.1.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\google.deepvariant.v1.6.1.docs.parquet
# ...

# %%
dfo.head(10)
# Out:
#                                                   id  keyword keyword_raw  \
# 0  allenai/scispacy/v0.5.5.code_comment.availabil...     down        down
# 1  allenai/scispacy/v0.5.5.code_comment.availabil...     down        down
# 2  allenai/scispacy/v0.5.5.code_comment.availabil...     down        down
# 3  allenai/scispacy/v0.5.5.code_comment.availabil...    avail       avail
# 4  allenai/scispacy/v0.5.5.code_comment.availabil...  consist     consist
# 5  allenai/scispacy/v0.5.5.code_comment.availabil...    incid       incid
# 6  allenai/scispacy/v0.5.5.code_comment.availabil...   servic      servic
# 7  allenai/scispacy/v0.5.5.code_comment.availabil...     down        down
# 8  allenai/scispacy/v0.5.5.code_comment.deployabi...  contain     contain
# 9  allenai/scispacy/v0.5.5.code_comment.deployabi...  contain     contain
#
#                                             sentence             qa  \
# 0  Given something that might be a URL (or might ...   availability
# ...

# %% [markdown]
# ## Stats

# %%
dfo[["prefilter_passed","s0_passed","s1_passed","s2_passed","s3_passed"]].value_counts(dropna=False).sort_index()
# Out:
# prefilter_passed  s0_passed  s1_passed  s2_passed  s3_passed
# False             NaN        NaN        NaN        NaN           68040
# True              False      NaN        NaN        NaN          990972
#                   True       True       False      NaN            7998
#                                         NaN        NaN           85608
#                                         True       NaN          211035
#                                                    False           446
#                                                    True            655
#                              NaN        False      NaN              17
#                                         NaN        NaN            1310
#                                         True       NaN            2098
#                              False      False      NaN            4858
#                                         NaN        NaN          129917
# ...

# %%
dfo.groupby(["prefilter_passed","s0_passed","s1_passed","s2_passed","s3_passed"], dropna=False).nsimilar.agg("sum").sort_index()
# Out:
# prefilter_passed  s0_passed  s1_passed  s2_passed  s3_passed
# False             NaN        NaN        NaN        NaN           103326
# True              False      NaN        NaN        NaN          1220672
#                   True       True       False      NaN            10373
#                                         NaN        NaN           104415
#                                         True       NaN           264228
#                                                    False            573
#                                                    True             999
#                              NaN        False      NaN               19
#                                         NaN        NaN             1340
#                                         True       NaN             2435
#                              False      False      NaN             6641
#                                         NaN        NaN           156217
# ...

# %%
dfo[dfo.prefilter_passed & dfo.s0_passed & dfo.s1_passed & dfo.s2_passed].drop_duplicates(["qa", "sentence"]).shape
# Out:
# (153582, 41)

# %%
dfo[dfo.prefilter_passed & dfo.s0_passed & dfo.s1_passed].drop_duplicates(["sentence"]).shape
# Out:
# (106185, 41)

# %% [markdown]
# ## Save merged data

# %%
stage.save_data(dfo, rows_limit=5000)
# Out:
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\merged\allenai.scispacy.v0.5.5.code_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\merged\allenai.scispacy.v0.5.5.code_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\merged\allenai.scispacy.v0.5.5.docs.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\merged\allenai.scispacy.v0.5.5.docs.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\merged\allenai.scispacy.v0.5.5.issue.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\merged\allenai.scispacy.v0.5.5.issue.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\merged\allenai.scispacy.v0.5.5.issue_comment.parquet
# ...
