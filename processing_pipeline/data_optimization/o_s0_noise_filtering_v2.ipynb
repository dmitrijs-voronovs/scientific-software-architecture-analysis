# %% [markdown]
# ## Load data

# %%
from processing_pipeline.data_optimization.stage_cfg import S0NoiseFiltering, COLUMNS_FOR_SPLITTING_DATA

stage = S0NoiseFiltering

# %%
df = stage.load_stage_df()
df.shape
# Out:
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering\allenai.scispacy.v0.5.5.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering\allenai.scispacy.v0.5.5.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering\allenai.scispacy.v0.5.5.issue.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering\allenai.scispacy.v0.5.5.issue_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering\allenai.scispacy.v0.5.5.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering\google.deepvariant.v1.6.1.code_comment.parquet
# ...

# %%
df.head()
# Out:
#                                             sentence  \
# 0  Given something that might be a URL (or might ...
# 1  Given a URL, look for the corresponding datase...
# 2  Download to temporary file, then copy to cache...
# 3  A candidate generator for entity linking to a ...
# 4  A spacy pipeline component which identifies en...
#
#                                            s0_prompt  s0_to_eliminate  \
# 0  \nYou are an expert in analyzing and categoriz...            False
# 1  \nYou are an expert in analyzing and categoriz...             True
# 2  \nYou are an expert in analyzing and categoriz...            False
# 3  \nYou are an expert in analyzing and categoriz...            False
# 4  \nYou are an expert in analyzing and categoriz...             True
#
#                                         s0_reasoning
# 0  This content describes a function that process...
# 1  This is a technical instruction or algorithm d...
# 2  This is a brief instruction about handling dow...
# ...

# %%
df.drop_duplicates(["sentence"]).shape
# Out:
# (524909, 4)

# %% [markdown]
# ## Optimize data

# %%
df = stage.apply_filters_till_current()
df.shape
# Out:
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.issue.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.issue_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\google.deepvariant.v1.6.1.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\google.deepvariant.v1.6.1.docs.parquet
# ...

# %%
df.head()
# Out:
#                                                    id  keyword keyword_raw  \
# 0   allenai/scispacy/v0.5.5.code_comment.availabil...     down        down
# 2   allenai/scispacy/v0.5.5.code_comment.availabil...     down        down
# 3   allenai/scispacy/v0.5.5.code_comment.availabil...    avail       avail
# 8   allenai/scispacy/v0.5.5.code_comment.deployabi...  contain     contain
# 11  allenai/scispacy/v0.5.5.code_comment.deployabi...  version     version
#
#                                              sentence             qa  \
# 0   Given something that might be a URL (or might ...   availability
# 2   Download to temporary file, then copy to cache...   availability
# 3   A candidate generator for entity linking to a ...   availability
# 8    in a pre-indexed approximate nearest neighbou...  deployability
# 11  Detects abbreviations using the algorithm in A...  deployability
#
#           source                                                url  \
# ...

# %% [markdown]
# ## Optimize data for the next stage

# %%
df = stage.optimize_df_for_next_stage(df)
df.shape
# Out:
# (402503, 4)

# %%
# with 14b model it takes 30s to process 20 items with 1 thread.
# df.shape[0] / 20 * 30 / 60 / 60
402503 / 60 * 30 / 60 / 60
# Out:
# 55.903194444444445

# %%
nitems = 50
time_s_per_50_items_tl = 1552
time_s_per_50_items_gl = 900
avg = (time_s_per_50_items_tl + time_s_per_50_items_gl) / 2
402503 / nitems * avg / 60 / 60 / 24 / 10
# Out:
# 11.422886064814815

# %%
df.head()
# Out:
#                qa                                           sentence  \
# 0    availability  Given something that might be a URL (or might ...
# 2    availability  Download to temporary file, then copy to cache...
# 3    availability  A candidate generator for entity linking to a ...
# 8   deployability   in a pre-indexed approximate nearest neighbou...
# 11  deployability  Detects abbreviations using the algorithm in A...
#
#                     repo_id        source
# 0   allenai/scispacy/v0.5.5  code_comment
# 2   allenai/scispacy/v0.5.5  code_comment
# 3   allenai/scispacy/v0.5.5  code_comment
# 8   allenai/scispacy/v0.5.5  code_comment
# 11  allenai/scispacy/v0.5.5  code_comment

# %%
stage.save_data(df)
# Out:
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering_o\allenai.scispacy.v0.5.5.code_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering_o\allenai.scispacy.v0.5.5.code_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering_o\allenai.scispacy.v0.5.5.docs.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering_o\allenai.scispacy.v0.5.5.docs.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering_o\allenai.scispacy.v0.5.5.issue.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s0_noise_filtering_o\allenai.scispacy.v0.5.5.issue.parquet
# ...

# %%
df.shape[0] * .7
# Out:
# 281752.1

# %%
df[COLUMNS_FOR_SPLITTING_DATA].value_counts()
# Out:
# repo_id                     source
# root-project/root/v6-32-06  code_comment     182617
#                             docs              60464
#                             issue_comment     51487
#                             issue             46308
# scverse/scanpy/1.10.2       issue_comment     22592
# google/deepvariant/v1.6.1   issue_comment     12823
# scverse/scanpy/1.10.2       issue              8805
# google/deepvariant/v1.6.1   issue              2782
# allenai/scispacy/v0.5.5     issue_comment      2439
# google/deepvariant/v1.6.1   code_comment       2175
# OpenGene/fastp/v0.23.4      issue_comment      1868
# allenai/scispacy/v0.5.5     issue              1501
# OpenGene/fastp/v0.23.4      issue              1444
# root-project/root/v6-32-06  wiki               1266
# scverse/scanpy/1.10.2       wiki                892
#                             code_comment        818
# google/deepvariant/v1.6.1   docs                770
# ...
