# %% [markdown]
# ## Load data

# %%
from processing_pipeline.data_optimization.stage_cfg import S0NoiseFiltering, COLUMNS_FOR_SPLITTING_DATA, S1QARelevance

stage = S1QARelevance

# %%
df = stage.load_stage_df()
df.shape
# Out:
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check\allenai.scispacy.v0.5.5.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check\allenai.scispacy.v0.5.5.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check\allenai.scispacy.v0.5.5.issue.from_40.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check\allenai.scispacy.v0.5.5.issue.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check\allenai.scispacy.v0.5.5.issue_comment.from_200.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check\allenai.scispacy.v0.5.5.issue_comment.from_220.parquet
# ...

# %%
df.head()
# Out:
#               qa                                           sentence  \
# 0   availability  Given something that might be a URL (or might ...
# 1   availability  Download to temporary file, then copy to cache...
# 2   availability  A candidate generator for entity linking to a ...
# 3  deployability   in a pre-indexed approximate nearest neighbou...
# 4  deployability  Detects abbreviations using the algorithm in A...
#
#                                            s1_prompt  \
# 0  \n### Data for Evaluation\n\n**1. Quality Attr...
# 1  \n### Data for Evaluation\n\n**1. Quality Attr...
# 2  \n### Data for Evaluation\n\n**1. Quality Attr...
# 3  \n### Data for Evaluation\n\n**1. Quality Attr...
# 4  \n### Data for Evaluation\n\n**1. Quality Attr...
#
#                      s1_analysis_problem_vs_solution  \
# 0  The text describes a solution for handling bot...
# 1  The text describes a solution (a mechanism) fo...
# 2  The text describes a mechanism for generating ...
# ...

# %%
df.drop_duplicates(stage.depends_on_fields).shape
# Out:
# (168819, 9)

# %% [markdown]
# ## Optimize data

# %%
df = stage.apply_filters_till_current()
df.shape
# Out:
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.docs.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.issue.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.issue_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\allenai.scispacy.v0.5.5.release.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\google.deepvariant.v1.6.1.code_comment.parquet
# Loaded C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\matched_o\google.deepvariant.v1.6.1.docs.parquet
# ...

# %%
df.head()
# Out:
#                                                    id keyword keyword_raw  \
# 0   allenai/scispacy/v0.5.5.code_comment.availabil...    down        down
# 1   allenai/scispacy/v0.5.5.code_comment.availabil...    down        down
# 11  allenai/scispacy/v0.5.5.code_comment.energy ef...    load        load
# 12  allenai/scispacy/v0.5.5.code_comment.energy ef...    load        load
# 13  allenai/scispacy/v0.5.5.code_comment.energy ef...  models      models
#
#                                              sentence                 qa  \
# 0   Given something that might be a URL (or might ...       availability
# 1   Download to temporary file, then copy to cache...       availability
# 11  In order to avoid loading spacy models repeate...  energy efficiency
# 12  In order to avoid loading spacy models repeate...  energy efficiency
# 13  In order to avoid loading spacy models repeate...  energy efficiency
#
#           source                                                url  \
# ...

# %% [markdown]
# ## Optimize data for the next stage

# %%
df_next = stage.optimize_df_for_next_stage(df)
df_next.shape
# Out:
# (61074, 3)

# %%
# with 14b model it takes 30s to process 20 items with 1 thread.
# df_next.shape[0] / 20 * 30 / 60 / 60
61074 / 60 * 30 / 60 / 60
# Out:
# 55.903194444444445

# %%
nitems = 20 * 10
time_s_per_50_items_tl = 160
time_s_per_50_items_gl = 300
avg = (time_s_per_50_items_tl + time_s_per_50_items_gl) / 2
61074 / nitems * avg / 60 / 60 / 24
# Out:
# 0.81290625

# %%
avg / nitems
# Out:
# 24.52

# %%
nitems = 20 * 10
time_to_process_s = 140
80074 / nitems * time_to_process_s / 60 / 60 / 24
# Out:
# 0.6487476851851852

# %%
time_to_process_s / nitems
# Out:
# 2.0

# %%
nitems = 8 * 5
time_to_process_s = 65
402503 / nitems * time_to_process_s / 60 / 60 / 24
# Out:
# 7.570224247685186

# %%
time_to_process_s / nitems
# Out:
# 1.625

# %%
nitems = 10 * 20
time_to_process_s = (45 +  90) / 2
402503 / nitems * time_to_process_s / 60 / 60 / 24
# Out:
# 1.5722773437500004

# %%
time_to_process_s / nitems
# Out:
# 0.3375

# %%
nitems = 10 * 20
time_to_process_s = (70 +  150) / 2
402503 / nitems * time_to_process_s / 60 / 60 / 24
# Out:
# 2.5622297453703706

# %%
time_to_process_s / nitems
# Out:
# 0.55

# %%
df_next.head()
# Out:
#                                              sentence  \
# 0   Given something that might be a URL (or might ...
# 1   Download to temporary file, then copy to cache...
# 11  In order to avoid loading spacy models repeate...
# 14  A candidate generator for entity linking to a ...
# 15  Load an approximate nearest neighbours index f...
#
#                     repo_id        source
# 0   allenai/scispacy/v0.5.5  code_comment
# 1   allenai/scispacy/v0.5.5  code_comment
# 11  allenai/scispacy/v0.5.5  code_comment
# 14  allenai/scispacy/v0.5.5  code_comment
# 15  allenai/scispacy/v0.5.5  code_comment

# %%
stage.save_data(df_next)
# Out:
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check_o\allenai.scispacy.v0.5.5.code_comment.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check_o\allenai.scispacy.v0.5.5.code_comment.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check_o\allenai.scispacy.v0.5.5.docs.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check_o\allenai.scispacy.v0.5.5.docs.parquet
# C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check_o\allenai.scispacy.v0.5.5.issue.parquet
# Saved C:\Users\Dmitrijs\Documents\myDocs\masters\courses\thesis\code\data\keywords_2\s1_qa_relevance_check_o\allenai.scispacy.v0.5.5.issue.parquet
# ...

# %%
df_next.shape[0] * .7
# Out:
# 42751.799999999996

# %%
df_next[COLUMNS_FOR_SPLITTING_DATA].value_counts()
# Out:
# repo_id                     source
# root-project/root/v6-32-06  code_comment     24651
#                             docs             15684
#                             issue             7926
#                             issue_comment     5387
# scverse/scanpy/1.10.2       issue_comment     2443
# google/deepvariant/v1.6.1   issue_comment     1629
# root-project/root/v6-32-06  wiki               595
# google/deepvariant/v1.6.1   code_comment       567
#                             issue              430
# scverse/scanpy/1.10.2       wiki               294
# allenai/scispacy/v0.5.5     issue              292
# google/deepvariant/v1.6.1   docs               288
# OpenGene/fastp/v0.23.4      issue              243
# scverse/scanpy/1.10.2       code_comment       203
#                             docs               117
# OpenGene/fastp/v0.23.4      code_comment       105
#                             docs                70
# google/deepvariant/v1.6.1   release             37
# ...
